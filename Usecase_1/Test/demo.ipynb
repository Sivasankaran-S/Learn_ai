# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import cv2
img = cv2.imread('invoice1.png')
show_img = cv2.imshow('Sample Image',img)
print(show_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# None

# %%
txt = pytesseract.image_to_string(img)
print(txt)
# Out:
# & INVOICE
#
# Ga ey Ren, Hawa, CA, USA 3006
#
# om ‘unity UntPace Tota
#
# mon 9
# Total $500
#
# Thank you!
#
# avert ronMarion
#
# fecomt Ne 2050-700" Samira Hadid
#
# Pay 5 ay 2025 123 anyanare st, Ay Cy, ST 12345
